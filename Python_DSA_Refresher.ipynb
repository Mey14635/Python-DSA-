# %% [markdown]
# Question 1

# %%
days=int(input("Enter any number of days "))

def second_in_day(days):
  #In a day we have 24*60*60 seconds
  seconds=days*86400
  print(seconds)

second_in_day(days)
# Out:
# Enter any number of days 3
# 259200

# %% [markdown]
# Question 2

# %%
radius=int(input("Enter the radius "))

def volume_of_sphere(radius):
  calculate=(4/3)*3.14*radius**3
  print("The Sphere is "+str(calculate))

volume_of_sphere(radius)
# Out:
# Enter the radius 4
# The Sphere is 267.94666666666666

# %% [markdown]
# Question 3

# %%
length=int(input("Enter the side length "))
def perimeter(length):
  calculate_perimeter=length+length+length+length
  print ("The perimeter is " + str(calculate_perimeter))
def area(length):
  calculate_area=length*2
  print ("The area is " + str(calculate_area))
perimeter(length)
area(length)
# Out:
# Enter the side length 5
# The perimeter is 20
# The area is 10

# %% [markdown]
# Question 4

# %%
# we ask user for input
character=input("Enter any single  character ")
# we have to ensure we are checking only one letter& in the alphabet
if len(character)==1 and character.isalpha():
  if character.isupper():
    print (f"' {character}' is a upper case character.")
  elif character.islower():
     print (f"' {character}' is a lower case character .")
else :
   print("Kindly enter a valid alphabetic letter ")
# Out:
# Enter any single  character O
# ' O' is a upper case character.

# %% [markdown]
# Question 5

# %%
x=0
y=20
while y>6:
  y=y-4
  x=x+(2/y)
print (f"The value of x is {x}")
# Out:
# The value of x is 1.0416666666666665

# %% [markdown]
# Question 6

# %%
arr=[]
print("Enter 5 numeric values  ")
for i in range (5):
  #so here we have to get input from users for the array
  values=int(input(f"Enter value {i+1}: "))
  #Then we populate the array
  arr.append(values)
total=sum(arr)
average=total/len(arr)
print (f"The average of all the numbers is : {average}")
# Out:
# Enter 5 numeric values
# Enter value 1: 3
# Enter value 2: 5
# Enter value 3: 3
# Enter value 4: 2
# Enter value 5: 1
# The average of all the numbers is : 2.8

# %% [markdown]
# Question 7

# %%
from google.colab import drive
drive.mount ('/content/drive')

path ='/content/codility_report.csv'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
pd.set_option('display.max_columns',None)
df =pd.read_csv(
    path,index_col=0
    )
df.head(1)
# Out:
#             Language Effective Time Spent Score
# Task
# AbsDistinct   Python               40 min  100%

# %% [markdown]
# ![Screenshot 2026-08-29 165602.png](data:image/png;base64,...)
